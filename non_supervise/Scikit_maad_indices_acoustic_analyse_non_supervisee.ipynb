# %%
import pandas as pd

df = pd.read_csv('concatenated_acoustic_indices.csv')

# %%
df
# Out:
#                           file_name  \
# 0      SMA04564_20220531_161726.wav
# 1      SMA04564_20220531_164702.wav
# 2      SMA04564_20220531_171702.wav
# 3      SMA04564_20220531_174702.wav
# 4      SMA04564_20220531_181702.wav
# ...                             ...
# 30544  SMA08828_20230708_070000.wav
# 30545  SMA08828_20230708_080000.wav
# 30546  SMA08828_20230708_090000.wav
# 30547  SMA08828_20230708_100000.wav
# 30548  SMA08828_20230708_110000.wav
#
#                                             station_name          ZCR  \
# 0               2022/Antras_Isard/SM4564_702L_Bleu/Data/    26.500000
# 1               2022/Antras_Isard/SM4564_702L_Bleu/Data/     0.000000
# 2               2022/Antras_Isard/SM4564_702L_Bleu/Data/     1.700000
# 3               2022/Antras_Isard/SM4564_702L_Bleu/Data/     0.166667
# 4               2022/Antras_Isard/SM4564_702L_Bleu/Data/   300.900000
# ...                                                  ...          ...
# 30544  2023/Valcebollère_Pla_des_Salines/SM8828_47L_R...  2664.816667
# 30545  2023/Valcebollère_Pla_des_Salines/SM8828_47L_R...  1991.066667
# 30546  2023/Valcebollère_Pla_des_Salines/SM8828_47L_R...  4111.283333
# 30547  2023/Valcebollère_Pla_des_Salines/SM8828_47L_R...  1752.250000
# 30548  2023/Valcebollère_Pla_des_Salines/SM8828_47L_R...  1052.216667
#
#           MEANt      VARt      SKEWt       KURTt       LEQt       BGNt  \
# 0     -0.071138  0.000943  18.844282  741.878546  70.804882 -20.364283
# 1     -0.072088  0.000051   0.003911    3.185880  70.220556 -20.692665
# 2     -0.072561  0.000240  -0.026333    4.415867  70.428267 -18.839075
# 3     -0.072394  0.000162  -0.011491    4.044512  70.347133 -19.333529
# 4     -0.072697  0.000586  -0.046556    6.230253  70.707393 -17.271708
# ...         ...       ...        ...         ...        ...        ...
# 30544  0.000966  0.000005   0.061751   15.494871  40.420251 -44.081135
# 30545  0.001092  0.000004   0.043957    3.429047  40.551362 -43.806730
# 30546  0.000574  0.000011   0.211090   14.242911  43.652024 -43.533936
# 30547  0.000544  0.000069  -0.030005    7.864743  51.411486 -35.396584
# 30548  0.001030  0.000061  -0.063343   14.384463  50.977159 -36.876617
#
#            SNRt  ...      TFSD  H_Havrda   H_Renyi  H_pairedShannon  \
# 0      3.631517  ...  0.755250  0.332384  2.930680         5.899521
# 1      0.043466  ...  0.711312  0.333275  4.325209         5.784790
# 2      0.173548  ...  0.745316  0.332956  3.391270         5.055228
# 3      0.093239  ...  0.729320  0.333169  3.808782         5.378254
# 4      0.602948  ...  0.755059  0.333002  3.456844         4.914801
# ...         ...  ...       ...       ...       ...              ...
# 30544  1.151237  ...  0.729231  0.333277  4.343159         6.263979
# 30545  0.529841  ...  0.711396  0.332787  3.206599         5.445871
# 30546  3.114562  ...  0.747528  0.332504  2.998246         5.563157
# 30547  2.119678  ...  0.789348  0.331662  2.647690         4.360874
# 30548  2.980982  ...  0.699311  0.331899  2.724291         4.297333
#
#             H_gamma  H_GiniSimpson      RAOQ       AGI  ROItotal   ROIcover
# 0      42662.896368       0.969171  0.652523  3.908220        20   4.562954
# 1      19461.220470       0.988569  0.890561  1.281302        71   4.644769
# 2      10507.448100       0.972643  0.408822  1.359625        78   1.551557
# 3      12718.746077       0.981275  0.570758  1.323778       243   2.307376
# 4       6822.684806       0.972457  0.225787  1.339269        87   0.479735
# ...             ...            ...       ...       ...       ...        ...
# 30544  42059.466244       0.990679  0.744602  1.574344       367   6.982161
# 30545  25623.385626       0.971321  0.335342  1.310117       178   3.861851
# 30546  33670.527993       0.966200  0.835676  2.200941       254  16.800731
# 30547   9980.878023       0.938909  0.214140  2.050552       265  11.338860
# 30548   6018.066826       0.943428  0.041343  1.425971       146   5.661561
#
# [30549 rows x 62 columns]

# %%
df.head(2).T
# Out:
#                                                       0  \
# file_name                  SMA04564_20220531_161726.wav
# station_name   2022/Antras_Isard/SM4564_702L_Bleu/Data/
# ZCR                                                26.5
# MEANt                                         -0.071138
# VARt                                           0.000943
# ...                                                 ...
# H_GiniSimpson                                  0.969171
# RAOQ                                           0.652523
# AGI                                             3.90822
# ROItotal                                             20
# ROIcover                                       4.562954
#
#                                                       1
# file_name                  SMA04564_20220531_164702.wav
# station_name   2022/Antras_Isard/SM4564_702L_Bleu/Data/
# ZCR                                                 0.0
# MEANt                                         -0.072088
# VARt                                           0.000051
# ...                                                 ...
# H_GiniSimpson                                  0.988569
# RAOQ                                           0.890561
# AGI                                            1.281302
# ROItotal                                             71
# ROIcover                                       4.644769
#
# [62 rows x 2 columns]

# %%
# Séparer la chaîne en plusieurs parties en utilisant le délimiteur "/"
df_split = df['station_name'].str.split('/', expand=True)

# Extraire la partie pertinente pour chaque colonne
df['Annee'] = df_split[0]
df['Transect'] = df_split[2].str.split('_').str[1].str[:-1]
df['Dynamique'] = df_split[2].str.split('_').str[2].replace({'Bleu': 'bleu', 'Rouge': 'rouge'})
df['Position'] = df_split[2].str.split('_').str[1].str[-1].replace({'L': 'lisiere', 'E': 'estive'})

# Afficher le DataFrame résultant
df.head(2).T

# df_split.head(2).T
# Out:
#                                                      0  \
# file_name                 SMA04564_20220531_161726.wav
# station_name  2022/Antras_Isard/SM4564_702L_Bleu/Data/
# ZCR                                               26.5
# MEANt                                        -0.071138
# VARt                                          0.000943
# ...                                                ...
# ROIcover                                      4.562954
# Transect                                           702
# Dynamique                                         bleu
# Position                                       lisiere
# Annee                                             2022
#
#                                                      1
# file_name                 SMA04564_20220531_164702.wav
# station_name  2022/Antras_Isard/SM4564_702L_Bleu/Data/
# ZCR                                                0.0
# MEANt                                        -0.072088
# VARt                                          0.000051
# ...                                                ...
# ROIcover                                      4.644769
# Transect                                           702
# Dynamique                                         bleu
# Position                                       lisiere
# Annee                                             2022
#
# [66 rows x 2 columns]

# %%
df.dtypes
# Out:
# file_name        object
# station_name     object
# ZCR             float64
# MEANt           float64
# VARt            float64
#                  ...
# ROIcover        float64
# Transect         object
# Dynamique        object
# Position         object
# Annee            object
# Length: 66, dtype: object

# %%
df

# %%
df_habitat = pd.read_csv('habitat_composition_by_station.csv')

# %%
df_habitat.head(2).T
# Out:
#                                         0         1
# LID                                     1         2
# Site                                    A         A
# Code                                   A1        A2
# Commune                           Mijanes   Mijanes
# LD                               Estagnet  Estagnet
# Transect                              375       375
# Dynamique                           rouge     rouge
# Position                           estive   lisiere
# Annee                                2022      2022
# SMMini                               5765      7108
# LAT                               42.6886   42.6899
# LON                                1.9722    1.9765
# total_edge_length_100                   0       150
# edge_density_100                      0.0   47.3186
# Shannon_landscape_diversity_100       0.0    0.0938
# grass_and_shub_cover_100            100.0   98.1073
# deciduous_forest_cover_100            0.0       0.0
# coniferous_forest_cover_100           0.0    1.8927
# mineral_cover_100                     0.0       0.0
# ice_and_snow_cover_100                  0         0
# water_cover_100                       0.0       0.0
# total_edge_length_250                   0      2600
# edge_density_250                      0.0  132.5854
# Shannon_landscape_diversity_250       0.0    0.4431
# grass_and_shub_cover_250            100.0   88.5263
# deciduous_forest_cover_250            0.0       0.0
# coniferous_forest_cover_250           0.0    7.5472
# mineral_cover_250                     0.0     0.408
# ice_and_snow_cover_250                  0         0
# water_cover_250                       0.0    3.5186
# total_edge_length_500                4740     11970
# edge_density_500                  60.4207  152.5813
# Shannon_landscape_diversity_500    0.1972    0.5587
# grass_and_shub_cover_500          95.9592   84.0408
# deciduous_forest_cover_500            0.0       0.0
# coniferous_forest_cover_500         1.963   11.3576
# mineral_cover_500                  2.0778    3.6201
# ice_and_snow_cover_500                0.0       0.0
# water_cover_500                       0.0    0.9815

# %%
df_habitat_important = df_habitat[['Annee', 'Transect', 'Dynamique', 'Position', 'LON', 'LAT', 'Commune', 'LD']]

df_habitat_important.head(2).T
# Out:
#                   0         1
# Annee          2022      2022
# Transect        375       375
# Dynamique     rouge     rouge
# Position     estive   lisiere
# LON          1.9722    1.9765
# LAT         42.6886   42.6899
# Commune     Mijanes   Mijanes
# LD         Estagnet  Estagnet

# %%
# @title Position vs Annee

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_habitat_important['Position'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_habitat_important, x='Annee', y='Position', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-31-5c0ef0fd216e>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df_habitat_important, x='Annee', y='Position', inner='stick', palette='Dark2')

# %%
# @title Dynamique vs Annee

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_habitat_important['Dynamique'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_habitat_important, x='Annee', y='Dynamique', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-30-0fe1d5b20ddc>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df_habitat_important, x='Annee', y='Dynamique', inner='stick', palette='Dark2')

# %%
# @title Annee vs Transect

from matplotlib import pyplot as plt
df_habitat_important.plot(kind='scatter', x='Annee', y='Transect', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Transect

from matplotlib import pyplot as plt
df_habitat_important['Transect'].plot(kind='hist', bins=20, title='Transect')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Convertir la colonne "Annee" en int64
df['Annee'] = df['Annee'].astype('int64')

# Convertir la colonne "Transect" en int64
df['Transect'] = df['Transect'].astype('int64')

# %%
# Supposons que vos DataFrames s'appellent df1 et df2
merged_df = pd.merge(df, df_habitat_important, on=['Annee', 'Transect', 'Dynamique', 'Position'], how='inner')

# %%
merged_df.head(2).T
# Out:
#                                                       0  \
# file_name                  SMA07113_20220531_174020.wav
# station_name  2022/Antras_Isard/SM7113_235L_Rouge/Data/
# ZCR                                         5592.433333
# MEANt                                           0.00108
# VARt                                           0.002056
# ...                                                 ...
# Annee                                              2022
# LON                                              0.8784
# LAT                                             42.8604
# Commune                                          Antras
# LD                                                Isard
#
#                                                       1
# file_name                  SMA07113_20220531_181002.wav
# station_name  2022/Antras_Isard/SM7113_235L_Rouge/Data/
# ZCR                                              5985.0
# MEANt                                         -0.000182
# VARt                                           0.000044
# ...                                                 ...
# Annee                                              2022
# LON                                              0.8784
# LAT                                             42.8604
# Commune                                          Antras
# LD                                                Isard
#
# [70 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Supprimer les colonnes 'file_name' et 'station_name'
merged_df = merged_df.drop(columns=['file_name', 'station_name'])

# Instancier LabelEncoder
label_encoder = LabelEncoder()

# Initialiser un dictionnaire pour stocker les correspondances
label_mapping = {}

# Appliquer LabelEncoding aux colonnes qualitatives
qualitative_cols = ['Dynamique', 'Position', 'Commune', 'LD']
for col in qualitative_cols:
    merged_df[col] = label_encoder.fit_transform(merged_df[col])
    # Stocker les correspondances dans le dictionnaire
    label_mapping[col] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# Afficher le dictionnaire de correspondance
print("Dictionnaire de correspondance des labels :")
for col, mapping in label_mapping.items():
    print(f"{col}: {mapping}")

# Afficher le DataFrame après les modifications
print("\nDataFrame après les modifications :")
merged_df.head(2).T
# Out:
# Dictionnaire de correspondance des labels :
# Dynamique: {'bleu': 0, 'rouge': 1}
# Position: {'estive': 0, 'lisiere': 1}
# Commune: {'Antras': 0, 'Appy': 1, 'Arrien-en-Bethmale': 2, 'Ascou': 3, 'Aston': 4, 'Aulus-les-Bains': 5, 'Bestiac': 6, 'Bethmale': 7, 'Bonac': 8, 'Bonac-Irazein': 9, 'Couflens': 10, 'Formiguères': 11, 'Gestiès': 12, 'Goulier': 13, 'Lercoul': 14, 'Les Angles': 15, 'Merens': 16, 'Miglos': 17, 'Mijanes': 18, 'Montferrier': 19, 'Montsegur': 20, 'Montségur': 21, 'Orgeix': 22, 'Orlu': 23, 'Saint-Lary': 24, 'Seix': 25, 'Sentein': 26, 'Ustou': 27, 'Valcebollère': 28}
# LD: {'Ayet': 0, "Col d'Escots": 1, 'Col de Grail': 2, 'Col de Pause': 3, "Col de l'Arech": 4, "Col de l'Herbe Soulette": 5, 'Col du Sasc': 6, 'Comte': 7, 'Coume': 8, 'Estagnet': 9, "Etang d'Appy": 10, 'Eychelle': 11, 'Eylie': 12, 'Frau': 13, 'Guzet-Neige': 14, 'Isard': 15, 'Le Clot': 16, "Mont d'Olmes": 17, 'Orle': 18, 'Pailheres': 19, 'Pic de Montbuou': 20, 'Pic du Midi de Bordes': 21, 'Pla de Montcamp': 22, 'Pla des Salines': 23, 'Plateau de Beille': 24, 'Pouill': 25, 'Puig del Pam': 26, 'RNCFS': 27, "Roc d'Aude": 28, 'Saubé': 29, 'Serra dels Alarbs': 30, 'Soularac': 31, 'Trabesses': 32, 'Trimouns': 33, 'Turon de Rose': 34, 'Val de Sos': 35}
#
# DataFrame après les modifications :
#                    0            1
# ZCR      5592.433333  5985.000000
# MEANt       0.001080    -0.000182
# VARt        0.002056     0.000044
# SKEWt      -7.353643     0.001908
# KURTt     305.336397     3.024766
# ...              ...          ...
# Annee    2022.000000  2022.000000
# LON         0.878400     0.878400
# LAT        42.860400    42.860400
# Commune     0.000000     0.000000
# LD         15.000000    15.000000
#
# [68 rows x 2 columns]

# %%
merged_df.to_csv('merged_indices_acoustic_with_LON_LAT.csv')

# %%
from google.colab import files
import os
# Télécharger le fichier CSV
files.download('merged_df.csv')
# Out:
#   adding: .config/ (stored 0%)
#   adding: .config/default_configs.db (deflated 98%)
#   adding: .config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: .config/logs/ (stored 0%)
#   adding: .config/logs/2024.02.13/ (stored 0%)
#   adding: .config/logs/2024.02.13/14.22.49.815065.log (deflated 57%)
#   adding: .config/logs/2024.02.13/14.22.40.428319.log (deflated 58%)
#   adding: .config/logs/2024.02.13/14.22.32.482030.log (deflated 86%)
#   adding: .config/logs/2024.02.13/14.21.57.851386.log (deflated 91%)
#   adding: .config/logs/2024.02.13/14.22.50.603761.log (deflated 56%)
#   adding: .config/logs/2024.02.13/14.22.23.056406.log (deflated 58%)
#   adding: .config/active_config (stored 0%)
#   adding: .config/gce (stored 0%)
#   adding: .config/configurations/ (stored 0%)
#   adding: .config/configurations/config_default (deflated 15%)
#   adding: .config/config_sentinel (stored 0%)
#   adding: .config/.last_survey_prompt.yaml (stored 0%)
#   adding: .config/.last_update_check.json (deflated 23%)
#   adding: concatenated_acoustic_indices.csv (deflated 57%)
#   adding: merged_indices_acoustic_with_LON_LAT.csv (deflated 56%)
#   adding: habitat_composition_by_station.csv (deflated 62%)
#   adding: sample_data/ (stored 0%)
#   adding: sample_data/README.md (deflated 42%)
#   adding: sample_data/anscombe.json (deflated 83%)
#   adding: sample_data/mnist_test.csv (deflated 88%)
#   adding: sample_data/california_housing_test.csv (deflated 76%)
#   adding: sample_data/mnist_train_small.csv (deflated 88%)
#   adding: sample_data/california_housing_train.csv (deflated 79%)

# %%
pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=cc7a005d4f963ec8bc163a8689a197e6e0f5208d27ada2af33650b65207e12a5
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built umap-learn
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.11 umap-learn-0.5.5

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Vérifier si merged_df contient des valeurs NaN
if merged_df.isna().any().any():
    print("Le DataFrame contient des valeurs NaN.")
else:
    print("Le DataFrame ne contient pas de valeurs NaN.")
# Out:
# Le DataFrame contient des valeurs NaN.

# %%
# Localiser les valeurs NaN dans merged_df
nan_locations = merged_df.isna()

# Afficher les positions des valeurs NaN
print("Positions des valeurs NaN :")
print(nan_locations)

# Afficher les lignes contenant des valeurs NaN
nan_rows = merged_df[nan_locations.any(axis=1)]
print("\nLignes contenant des valeurs NaN :")
nan_rows.T
# Out:
# Positions des valeurs NaN :
#          ZCR  MEANt   VARt  SKEWt  KURTt   LEQt   BGNt   SNRt    MED     Ht  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 30301  False  False  False  False  False  False  False  False  False  False
# 30302  False  False  False  False  False  False  False  False  False  False
# 30303  False  False  False  False  False  False  False  False  False  False
# 30304  False  False  False  False  False  False  False  False  False  False
# 30305  False  False  False  False  False  False  False  False  False  False
#
#        ...  ROItotal  ROIcover  Transect  Dynamique  Position  Annee    LON  \
# 0      ...     False     False     False      False     False  False  False
# 1      ...     False     False     False      False     False  False  False
# 2      ...     False     False     False      False     False  False  False
# 3      ...     False     False     False      False     False  False  False
# 4      ...     False     False     False      False     False  False  False
# ...    ...       ...       ...       ...        ...       ...    ...    ...
# 30301  ...     False     False     False      False     False  False  False
# 30302  ...     False     False     False      False     False  False  False
# 30303  ...     False     False     False      False     False  False  False
# 30304  ...     False     False     False      False     False  False  False
# 30305  ...     False     False     False      False     False  False  False
#
#          LAT  Commune     LD
# 0      False    False  False
# 1      False    False  False
# 2      False    False  False
# 3      False    False  False
# 4      False    False  False
# ...      ...      ...    ...
# 30301  False    False  False
# 30302  False    False  False
# 30303  False    False  False
# 30304  False    False  False
# 30305  False    False  False
#
# [30306 rows x 68 columns]
#
# Lignes contenant des valeurs NaN :
#                 698          699           701          730          924    \
# ZCR      2.407000e+02   399.266667  3.348667e+02   774.216667   464.600000
# MEANt   -1.890872e-03    -0.002032 -1.937871e-03    -0.130874    -0.002772
# VARt     7.400352e-07     0.000001  9.310949e-07     0.264997     0.000003
# SKEWt   -4.162979e-02    -0.031503 -5.765238e-02    -0.126513    -0.048935
# KURTt    2.970591e+00     2.954122  2.973841e+00     2.269907     3.127118
# ...               ...          ...           ...          ...          ...
# Annee    2.022000e+03  2022.000000  2.022000e+03  2022.000000  2022.000000
# LON      1.954100e+00     1.954100  1.954100e+00     1.954100     1.972700
# LAT      4.271950e+01    42.719500  4.271950e+01    42.719500    42.721400
# Commune  3.000000e+00     3.000000  3.000000e+00     3.000000     3.000000
# LD       1.900000e+01    19.000000  1.900000e+01    19.000000    19.000000
#
#                1012         1663          1961          1962          1964   \
# ZCR       591.983333  2091.533333  8.933333e+00  2.566667e+00  1.333333e-01
# MEANt      -0.001900    -0.002353 -2.903109e-03 -3.048181e-03 -3.470372e-03
# VARt        0.000001     0.000006  6.634897e-07  6.695087e-07  6.331159e-07
# SKEWt      -0.077432    -0.025808  3.912621e-02 -8.392160e-03 -3.440672e-02
# KURTt       3.193818     2.978873  3.157486e+00  3.050192e+00  3.075694e+00
# ...              ...          ...           ...           ...           ...
# Annee    2022.000000  2022.000000  2.022000e+03  2.022000e+03  2.022000e+03
# LON         1.972700     1.788600  1.787400e+00  1.787400e+00  1.787400e+00
# LAT        42.721400    42.790300  4.279140e+01  4.279140e+01  4.279140e+01
# Commune     3.000000     6.000000  6.000000e+00  6.000000e+00  6.000000e+00
# LD         19.000000    33.000000  3.300000e+01  3.300000e+01  3.300000e+01
#
#          ...        25276        25277         26362         26584  \
# ZCR      ...     0.000000     0.000000  1.594667e+02  8.300500e+02
# MEANt    ...    -0.075144    -0.075016  1.204738e-03  1.033005e-03
# VARt     ...     0.000019     0.000007  2.169061e-07  3.332773e-07
# SKEWt    ...     0.010527    -0.017549 -1.576896e-02 -1.245715e-02
# KURTt    ...     5.992362     4.755556  3.151221e+00  2.952656e+00
# ...      ...          ...          ...           ...           ...
# Annee    ...  2023.000000  2023.000000  2.023000e+03  2.023000e+03
# LON      ...     1.848200     1.848200  8.636000e-01  8.650000e-01
# LAT      ...    42.845500    42.845500  4.288690e+01  4.288600e+01
# Commune  ...    20.000000    20.000000  2.400000e+01  2.400000e+01
# LD       ...    13.000000    13.000000  5.000000e+00  5.000000e+00
#
#                 26587         26659         28004         28028        29294  \
# ZCR      2.096667e+01  1.551667e+01  1.741667e+02  2.321667e+01   656.000000
# MEANt    1.847720e-03  1.936425e-03  1.483386e-03  1.695056e-03     0.001848
# VARt     3.398585e-07  3.413832e-07  3.688188e-07  2.896917e-07     0.000001
# SKEWt    2.822810e-03 -5.576045e-02  2.544467e-02  3.787784e-02    -0.122259
# KURTt    2.965481e+00  3.038742e+00  3.094681e+00  3.066778e+00     3.114242
# ...               ...           ...           ...           ...          ...
# Annee    2.023000e+03  2.023000e+03  2.023000e+03  2.023000e+03  2023.000000
# LON      8.650000e-01  8.650000e-01  1.143900e+00  1.143900e+00     1.302000
# LAT      4.288600e+01  4.288600e+01  4.278310e+01  4.278310e+01    42.766500
# Commune  2.400000e+01  2.400000e+01  2.500000e+01  2.500000e+01    27.000000
# LD       5.000000e+00  5.000000e+00  2.000000e+01  2.000000e+01     1.000000
#
#                 30082
# ZCR      8.822500e+02
# MEANt    1.116962e-03
# VARt     4.248145e-07
# SKEWt    9.610744e-02
# KURTt    2.500892e+00
# ...               ...
# Annee    2.023000e+03
# LON      2.058500e+00
# LAT      4.237170e+01
# Commune  2.800000e+01
# LD       2.300000e+01
#
# [68 rows x 866 columns]

# %%
# Afficher les valeurs de la ligne 698
# print(merged_df.iloc[697])  # L'index de la ligne est 697 car l'indexation commence à partir de 0
for feature, val in merged_df.iloc[698].items():
  print(feature, ':', val)
# Out:
# ZCR : 240.7
# MEANt : -0.0018908725
# VARt : 7.400352e-07
# SKEWt : -0.0416297877273923
# KURTt : 2.9705906018007155
# LEQt : 39.37084436416626
# BGNt : -47.41958
# SNRt : 0.0997371673583984
# MED : 0.0042561935
# Ht : 0.9977829214618692
# ACTtFraction : 0.0
# ACTtCount : 0.0
# ACTtMean : nan
# EVNtFraction : 0.0
# EVNtMean : 0.0
# EVNtCount : 0.0
# MEANf : 2.5967442e-05
# VARf : 7.078304e-10
# SKEWf : 3.8018391064504176
# KURTf : 21.79807123992023
# NBPEAKS : 2.0
# LEQf : 31.498214667987337
# ENRf : -61.50178536902597
# BGNf : -63.57634738903424
# SNRf : 2.074562020008265
# Hf : 0.7628468576609437
# EAS : 0.0001151584685321
# ECU : 0.0211098262975029
# ECV : 0.0169569455917767
# EPS : 0.184736406848563
# EPS_KURT : 23.90386294399737
# EPS_SKEW : 3.094688908318429
# ACI : 296.36475
# NDSI : -0.5561277
# rBA : 0.28524154
# AnthroEnergy : 0.001137279
# BioEnergy : 0.0003243992
# BI : 2514.18325
# ROU : 0.0016352301
# ADI : 2.073667497270208
# AEI : 0.2306746203810883
# LFC : 0.1292751005664559
# MFC : 0.1272547739746912
# HFC : 0.2390608324439701
# ACTspFract : 0.1274982073772678
# ACTspCount : 238.931640625
# ACTspMean : 5.486452579498291
# EVNspFract : 0.0017092449306296
# EVNspMean : 0.0639778093434343
# EVNspCount : 0.0127088686265349
# TFSD : 0.6611269
# H_Havrda : 0.3329878163834412
# H_Renyi : 3.4359283447265625
# H_pairedShannon : 5.7476454
# H_gamma : 34308.964006984424
# H_GiniSimpson : 0.977874333038926
# RAOQ : 0.4283949710447068
# AGI : 1.2012541
# ROItotal : 38.0
# ROIcover : 0.1206893676627534
# Transect : 529.0
# Dynamique : 0.0
# Position : 0.0
# Annee : 2022.0
# LON : 1.9541
# LAT : 42.7195
# Commune : 3.0
# LD : 19.0

# %%
# Compter le nombre de NaN par colonne
nan_count = merged_df.isna().sum()

# Afficher le nombre de NaN par colonne
print("Nombre de NaN par colonne :")
for feature, val in nan_count.items():
  print(feature, ":", val)
# Out:
# Nombre de NaN par colonne :
# ZCR : 0
# MEANt : 0
# VARt : 0
# SKEWt : 0
# KURTt : 0
# LEQt : 0
# BGNt : 0
# SNRt : 0
# MED : 0
# Ht : 247
# ACTtFraction : 0
# ACTtCount : 0
# ACTtMean : 627
# EVNtFraction : 0
# EVNtMean : 0
# EVNtCount : 0
# MEANf : 0
# VARf : 0
# SKEWf : 0
# KURTf : 0
# NBPEAKS : 0
# LEQf : 0
# ENRf : 0
# BGNf : 0
# SNRf : 0
# Hf : 0
# EAS : 0
# ECU : 0
# ECV : 0
# EPS : 0
# EPS_KURT : 0
# EPS_SKEW : 0
# ACI : 0
# NDSI : 0
# rBA : 0
# AnthroEnergy : 0
# BioEnergy : 0
# BI : 0
# ROU : 0
# ADI : 0
# AEI : 0
# LFC : 0
# MFC : 0
# HFC : 0
# ACTspFract : 0
# ACTspCount : 0
# ACTspMean : 0
# EVNspFract : 0
# EVNspMean : 0
# EVNspCount : 0
# TFSD : 241
# H_Havrda : 0
# H_Renyi : 0
# H_pairedShannon : 0
# H_gamma : 0
# H_GiniSimpson : 0
# RAOQ : 0
# AGI : 0
# ROItotal : 0
# ROIcover : 0
# Transect : 0
# Dynamique : 0
# Position : 0
# Annee : 0
# LON : 0
# LAT : 0
# Commune : 0
# LD : 0

# %%
print("Nombre total de Not a Number : ", nan_count.sum())
# Out:
# Nombre total de Not a Number :  1115

# %%
# Supprimer les lignes contenant des valeurs NaN
merged_df = merged_df.dropna()

# Réinitialiser les index après la suppression des lignes
merged_df = merged_df.reset_index(drop=True)

# %%
merged_df
# Out:
#                ZCR     MEANt      VARt     SKEWt       KURTt       LEQt  \
# 0      5592.433333  0.001080  0.002056 -7.353643  305.336397  66.152530
# 1      5985.000000 -0.000182  0.000044  0.001908    3.024766  49.441233
# 2      5557.816667 -0.000722  0.000051 -0.013470    6.052949  50.141978
# 3      5238.666667 -0.000875  0.000041  0.000330    4.578263  49.182520
# 4      4607.933333 -0.000830  0.000079 -0.068094   23.844919  52.040429
# ...            ...       ...       ...       ...         ...        ...
# 29435  2664.816667  0.000966  0.000005  0.061751   15.494871  40.420251
# 29436  1991.066667  0.001092  0.000004  0.043957    3.429047  40.551362
# 29437  4111.283333  0.000574  0.000011  0.211090   14.242911  43.652024
# 29438  1752.250000  0.000544  0.000069 -0.030005    7.864743  51.411486
# 29439  1052.216667  0.001030  0.000061 -0.063343   14.384463  50.977159
#
#             BGNt       SNRt       MED        Ht  ...  ROItotal   ROIcover  \
# 0     -33.730106  18.710289  0.020582  0.571475  ...        24  14.223211
# 1     -33.699547   0.184051  0.020655  0.995639  ...       229   5.669586
# 2     -34.221490   1.425626  0.019450  0.964310  ...       206  13.571822
# 3     -34.435130   0.829582  0.018978  0.976875  ...       263   8.841069
# 4     -35.056084   3.847526  0.017668  0.878895  ...       142  15.343391
# ...          ...        ...       ...       ...  ...       ...        ...
# 29435 -44.081135   1.151237  0.006251  0.957737  ...       367   6.982161
# 29436 -43.806730   0.529841  0.006452  0.988873  ...       178   3.861851
# 29437 -43.533936   3.114562  0.006657  0.914472  ...       254  16.800731
# 29438 -35.396584   2.119678  0.016989  0.937993  ...       265  11.338860
# 29439 -36.876617   2.980982  0.014327  0.910490  ...       146   5.661561
#
#        Transect  Dynamique  Position  Annee     LON      LAT  Commune  LD
# 0           235          1         1   2022  0.8784  42.8604        0  15
# 1           235          1         1   2022  0.8784  42.8604        0  15
# 2           235          1         1   2022  0.8784  42.8604        0  15
# 3           235          1         1   2022  0.8784  42.8604        0  15
# 4           235          1         1   2022  0.8784  42.8604        0  15
# ...         ...        ...       ...    ...     ...      ...      ...  ..
# 29435        47          1         1   2023  2.0585  42.3717       28  23
# 29436        47          1         1   2023  2.0585  42.3717       28  23
# 29437        47          1         1   2023  2.0585  42.3717       28  23
# 29438        47          1         1   2023  2.0585  42.3717       28  23
# 29439        47          1         1   2023  2.0585  42.3717       28  23
#
# [29440 rows x 68 columns]

# %%
# ACP
pca = PCA(n_components=2)
pca_result = pca.fit_transform(merged_df)

# t-SNE
tsne = TSNE(n_components=2)
tsne_result = tsne.fit_transform(merged_df)

# uMAP
umap_result = umap.UMAP(n_components=2).fit_transform(merged_df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Créer un tracé avec 3 sous-tracés (subplots)
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Affichage des résultats de l'ACP sur le premier subplot
sns.scatterplot(x=pca_result[:,0], y=pca_result[:,1], ax=axes[0])
axes[0].set_title('Analyse en Composantes Principales (ACP)')

# Affichage des résultats de t-SNE sur le deuxième subplot
sns.scatterplot(x=tsne_result[:,0], y=tsne_result[:,1], ax=axes[1])
axes[1].set_title('t-SNE')

# Affichage des résultats de uMAP sur le troisième subplot
sns.scatterplot(x=umap_result[:,0], y=umap_result[:,1], ax=axes[2])
axes[2].set_title('uMAP')

# Afficher le tracé avec les sous-tracés
plt.tight_layout()
plt.show()

# %%
# !pip install mplleaflet
# !pip install osmnx
# !pip install cartopy
# !pip install pyquickhelper
# !pip install dbfread
# !pip install papierstat
# !pip install pyensae
# !pip install umap-learn
# Out:
# Collecting mplleaflet
#   Downloading mplleaflet-0.0.5.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mplleaflet) (3.1.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mplleaflet) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mplleaflet) (2.1.5)
# Building wheels for collected packages: mplleaflet
#   Building wheel for mplleaflet (setup.py) ... done
#   Created wheel for mplleaflet: filename=mplleaflet-0.0.5-py3-none-any.whl size=28565 sha256=9cbb6f3c1118aeb50bbfbb8d6057f0ea3c65411165aedef132bc5a2f61242fbe
#   Stored in directory: /root/.cache/pip/wheels/0d/00/a9/595e650d2e0a5ca4119c0f6e03dfd1093e5d67fe2c0e5d49f0
# Successfully built mplleaflet
# Installing collected packages: mplleaflet
# Successfully installed mplleaflet-0.0.5
# Collecting osmnx
#   Downloading osmnx-1.9.1-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: geopandas>=0.12 in /usr/local/lib/python3.10/dist-packages (from osmnx) (0.13.2)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.10/dist-packages (from osmnx) (3.2.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.25.2)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from osmnx) (1.5.3)
# Requirement already satisfied: requests>=2.27 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.31.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (1.9.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (23.2)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.12->osmnx) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->osmnx) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27->osmnx) (2024.2.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (23.2.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (67.7.2)
# Installing collected packages: osmnx
# Successfully installed osmnx-1.9.1
# Collecting cartopy
#   Downloading Cartopy-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 66.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from cartopy) (1.25.2)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.7.1)
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.10/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.1.0->cartopy) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Installing collected packages: cartopy
# Successfully installed cartopy-0.22.0
# Collecting pyquickhelper
#   Downloading pyquickhelper-1.12.3823-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 34.0 MB/s eta 0:00:00
# Collecting fire (from pyquickhelper)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pyquickhelper) (1.25.2)
# Collecting pyquicksetup>=0.2 (from pyquickhelper)
#   Downloading pyquicksetup-0.2.4.tar.gz (5.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pyquicksetup>=0.2->pyquickhelper) (67.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->pyquickhelper) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->pyquickhelper) (2.4.0)
# Building wheels for collected packages: pyquicksetup, fire
#   Building wheel for pyquicksetup (setup.py) ... done
#   Created wheel for pyquicksetup: filename=pyquicksetup-0.2.4-py3-none-any.whl size=6710 sha256=d36941f317134dc320ce3e5128c59ece8d32030c124ea26bc8fd3d5b0285fcdb
#   Stored in directory: /root/.cache/pip/wheels/37/be/8e/de24987fe1693d9c54ac697d5dfa8762422350c6d5732abe0f
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=551cb68373ddce0afa90cad84231cc309f782b051191daa59a20db7ec2872a27
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built pyquicksetup fire
# Installing collected packages: pyquicksetup, fire, pyquickhelper
# Successfully installed fire-0.5.0 pyquickhelper-1.12.3823 pyquicksetup-0.2.4
# Collecting dbfread
#   Downloading dbfread-2.0.7-py2.py3-none-any.whl (20 kB)
# Installing collected packages: dbfread
# Successfully installed dbfread-2.0.7
# Collecting papierstat
#   Downloading papierstat-0.2.408-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from papierstat) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from papierstat) (1.5.3)
# Collecting mlinsights (from papierstat)
#   Downloading mlinsights-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 46.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from papierstat) (3.7.1)
# Collecting pandas-streaming (from papierstat)
#   Downloading pandas_streaming-0.5.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.0->papierstat) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.0->papierstat) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.0->papierstat) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.0->papierstat) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->papierstat) (2.8.2)
# Collecting onnx>=1.14.0 (from mlinsights->papierstat)
#   Downloading onnx-1.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 47.1 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->papierstat) (2023.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.14.0->mlinsights->papierstat) (3.20.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->papierstat) (1.16.0)
# Installing collected packages: onnx, mlinsights, pandas-streaming, papierstat
# Successfully installed mlinsights-0.5.0 onnx-1.15.0 pandas-streaming-0.5.0 papierstat-0.2.408
# Collecting pyensae
#   Downloading pyensae-1.3.967-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.1/493.1 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: pyquickhelper>=1.8 in /usr/local/lib/python3.10/dist-packages (from pyensae) (1.12.3823)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from pyensae) (1.25.2)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from pyensae) (1.5.3)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.10/dist-packages (from pyensae) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->pyensae) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->pyensae) (2023.4)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/dist-packages (from pyquickhelper>=1.8->pyensae) (0.5.0)
# Requirement already satisfied: pyquicksetup>=0.2 in /usr/local/lib/python3.10/dist-packages (from pyquickhelper>=1.8->pyensae) (0.2.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pyquicksetup>=0.2->pyquickhelper>=1.8->pyensae) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->pyensae) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->pyquickhelper>=1.8->pyensae) (2.4.0)
# Installing collected packages: pyensae
# Successfully installed pyensae-1.3.967
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from cartopy.io.img_tiles import OSM

# %%
lon_min, lon_max, lat_min, lat_max = 0, 3, 41, 44

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
ax.set_extent([lon_min, lon_max, lat_min, lat_max])

imagery = OSM()
ax.add_image(imagery, 8)
# plus c'est grand, plus c'est précis, plus ça prend du temps

ax.plot(merged_df.LON, merged_df.LAT, '.')
ax.set_title('France');

# %%
from sklearn.cluster import KMeans

# Effectuer le clustering K-means sur les données ACP
kmeans = KMeans(n_clusters=4, random_state=42)
cluster_labels = kmeans.fit_predict(pca_result)

# Encodage de chaque point avec l'identifiant de son cluster
merged_df['Cluster_ACP'] = cluster_labels

# Effectuer le clustering K-means sur les données t-SNE
kmeans_tsne = KMeans(n_clusters=4, random_state=42)
cluster_labels_tsne = kmeans_tsne.fit_predict(tsne_result)

# Encodage de chaque point avec l'identifiant de son cluster
merged_df['Cluster_tSNE'] = cluster_labels_tsne

# Effectuer le clustering K-means sur les données UMAP
kmeans_umap = KMeans(n_clusters=4, random_state=42)
cluster_labels_umap = kmeans_umap.fit_predict(umap_result)

# Encodage de chaque point avec l'identifiant de son cluster
merged_df['Cluster_uMAP'] = cluster_labels_umap

# Affichage des cinq premières lignes pour vérification
print(merged_df.T)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#                     0            1            2            3            4      \
# ZCR           5592.433333  5985.000000  5557.816667  5238.666667  4607.933333
# MEANt            0.001080    -0.000182    -0.000722    -0.000875    -0.000830
# VARt             0.002056     0.000044     0.000051     0.000041     0.000079
# SKEWt           -7.353643     0.001908    -0.013470     0.000330    -0.068094
# KURTt          305.336397     3.024766     6.052949     4.578263    23.844919
# ...                   ...          ...          ...          ...          ...
# Commune          0.000000     0.000000     0.000000     0.000000     0.000000
# LD              15.000000    15.000000    15.000000    15.000000    15.000000
# Cluster_ACP      0.000000     3.000000     2.000000     2.000000     2.000000
# Cluster_tSNE     2.000000     1.000000     2.000000     2.000000     2.000000
# Cluster_uMAP     3.000000     0.000000     3.000000     3.000000     3.000000
#
#                     5            6            7            8            9      \
# ZCR           3567.716667  3670.383333  2692.033333  3049.000000  3244.750000
# MEANt           -0.001439    -0.000817    -0.001713    -0.001820    -0.001451
# VARt             0.000026     0.000088     0.000029     0.000027     0.000031
# SKEWt           -0.012826    -0.103502    -0.004122    -0.009150    -0.007707
# KURTt            3.054485    26.380809     3.083231     3.053271     3.031074
# ...                   ...          ...          ...          ...          ...
# Commune          0.000000     0.000000     0.000000     0.000000     0.000000
# LD              15.000000    15.000000    15.000000    15.000000    15.000000
# Cluster_ACP      3.000000     2.000000     3.000000     3.000000     3.000000
# Cluster_tSNE     1.000000     2.000000     1.000000     0.000000     0.000000
# Cluster_uMAP     0.000000     3.000000     0.000000     0.000000     0.000000
#
#               ...        29430        29431        29432        29433  \
# ZCR           ...  1256.450000  2062.616667  1150.166667  1391.966667
# MEANt         ...     0.000902     0.000950     0.001274     0.000780
# VARt          ...     0.000031     0.000001     0.000009     0.000019
# SKEWt         ...    -0.075585     0.049079    -0.127160    -0.126041
# KURTt         ...    24.681527     3.700099    36.037677    11.610991
# ...           ...          ...          ...          ...          ...
# Commune       ...    28.000000    28.000000    28.000000    28.000000
# LD            ...    23.000000    23.000000    23.000000    23.000000
# Cluster_ACP   ...     1.000000     3.000000     1.000000     1.000000
# Cluster_tSNE  ...     3.000000     1.000000     3.000000     3.000000
# Cluster_uMAP  ...     1.000000     0.000000     1.000000     1.000000
#
#                     29434        29435        29436        29437        29438  \
# ZCR           1243.466667  2664.816667  1991.066667  4111.283333  1752.250000
# MEANt            0.001532     0.000966     0.001092     0.000574     0.000544
# VARt             0.000005     0.000005     0.000004     0.000011     0.000069
# SKEWt            0.107098     0.061751     0.043957     0.211090    -0.030005
# KURTt           15.328842    15.494871     3.429047    14.242911     7.864743
# ...                   ...          ...          ...          ...          ...
# Commune         28.000000    28.000000    28.000000    28.000000    28.000000
# LD              23.000000    23.000000    23.000000    23.000000    23.000000
# Cluster_ACP      1.000000     2.000000     3.000000     2.000000     1.000000
# Cluster_tSNE     0.000000     2.000000     0.000000     1.000000     0.000000
# Cluster_uMAP     2.000000     3.000000     0.000000     0.000000     1.000000
#
#                     29439
# ZCR           1052.216667
# MEANt            0.001030
# VARt             0.000061
# SKEWt           -0.063343
# KURTt           14.384463
# ...                   ...
# Commune         28.000000
# LD              23.000000
# Cluster_ACP      1.000000
# Cluster_tSNE     3.000000
# Cluster_uMAP     1.000000
#
# [71 rows x 29440 columns]

# %%
cluster_colors = {0: 'blue', 1: 'red', 2: 'orange', 3: 'green'}
cluster_colors_tsne = {0: 'blue', 1: 'red', 2: 'orange', 3: 'green'}
cluster_colors_umap = {0: 'blue', 1: 'red', 2: 'orange', 3: 'green'}
lon_min, lon_max, lat_min, lat_max = 0, 3, 42, 43

# Création de la figure et des sous-graphiques
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Tracé ACP
axs[0].set_title('ACP')
for cluster_label, color in cluster_colors.items():
    df_cluster = merged_df[merged_df['Cluster_ACP'] == cluster_label]
    axs[0].scatter(pca_result[df_cluster.index, 0], pca_result[df_cluster.index, 1], c=color, label=f'Cluster {cluster_label}')
axs[0].legend()

# Tracé t-SNE
axs[1].set_title('tSNE')
for cluster_label, color in cluster_colors_tsne.items():
    df_cluster_tsne = merged_df[merged_df['Cluster_tSNE'] == cluster_label]
    axs[1].scatter(tsne_result[df_cluster_tsne.index, 0], tsne_result[df_cluster_tsne.index, 1], c=color, label=f'Cluster {cluster_label}')
axs[1].legend()

# Tracé uMAP
axs[2].set_title('uMAP')
for cluster_label, color in cluster_colors_umap.items():
    df_cluster_umap = merged_df[merged_df['Cluster_uMAP'] == cluster_label]
    axs[2].scatter(umap_result[df_cluster_umap.index, 0], umap_result[df_cluster_umap.index, 1], c=color, label=f'Cluster {cluster_label}')
axs[2].legend()

plt.tight_layout()
plt.show()

# Définir les couleurs pour chaque cluster
cluster_colors_acp = {0: 'blue', 1: 'red', 2: 'orange', 3: 'green'}


# Créer une nouvelle figure et les sous-tracés
fig, axs = plt.subplots(1, 3, figsize=(18, 6), subplot_kw={'projection': ccrs.PlateCarree()})

# Tracer la carte de la France pour chaque représentation
for ax, cluster_colors, representation in zip(axs, [cluster_colors_acp, cluster_colors_tsne, cluster_colors_umap], ['ACP', 'tSNE', 'uMAP']):
    ax.set_extent([lon_min, lon_max, lat_min, lat_max])
    ax.add_feature(cfeature.OCEAN)
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')

    # Tracer les points en fonction de leur cluster
    for cluster_label, color in cluster_colors.items():
        df_cluster = merged_df[merged_df[f'Cluster_{representation}'] == cluster_label]
        ax.plot(df_cluster['LON'], df_cluster['LAT'], '.', color=color, label=f'Cluster {cluster_label}', transform=ccrs.PlateCarree())

    ax.set_title(f'France with clustered points ({representation})')
    ax.legend()


# Créer une nouvelle figure et les sous-tracés
fig, axs = plt.subplots(1, 3, figsize=(18, 6), subplot_kw={'projection': ccrs.PlateCarree()})

# Tracer la carte de la France pour chaque représentation
for ax, cluster_colors, representation in zip(axs, [cluster_colors_acp, cluster_colors_tsne, cluster_colors_umap], ['ACP', 'tSNE', 'uMAP']):
    ax.set_extent([lon_min, lon_max, lat_min, lat_max])

    imagery = OSM()
    ax.add_image(imagery, 8)

    # Tracer les points en fonction de leur cluster
    for cluster_label, color in cluster_colors.items():
        df_cluster = merged_df[merged_df[f'Cluster_{representation}'] == cluster_label]
        ax.plot(df_cluster['LON'], df_cluster['LAT'], '.', color=color, label=f'Cluster {cluster_label}', transform=ccrs.PlateCarree())

    ax.set_title(f'France with clustered points ({representation})')
    ax.legend()


plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_ocean.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /usr/local/lib/python3.10/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
