# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import re

def separate_integers_letters(string):
    integers = ''.join(re.findall(r'\d+', string))
    letters = ''.join(re.findall(r'[a-zA-Z]+', string))
    return integers, letters

# %%
dico_encodage = {'E_Bleu': 1, 'E_Rouge': 2, 'L_Bleu': 3, 'L_Rouge': 4}
print(dico_encodage)
# Out:
# {'E_Bleu': 1, 'E_Rouge': 2, 'L_Bleu': 3, 'L_Rouge': 4}

# %%
import pandas as pd

def add_labels(df):

  for index, row in df.iterrows():
    station_name_parts = row['station_name'].split('/')
    position_dynamique = station_name_parts[2]
    position_dynamique_parts = position_dynamique.split('_')
    _, position = separate_integers_letters(position_dynamique_parts[1])
    dynamique = position_dynamique_parts[2]

    position_dynamique = position + '_' + dynamique

    df.loc[index, 'label'] = dico_encodage[position_dynamique]

  return df

# %%
from sklearn.metrics import accuracy_score

def train_and_predict(model, X_train, y_train, X_test, y_test):
    # Entraîner le modèle sur l'ensemble de données d'entraînement
    model.fit(X_train, y_train)

    # Prédire les étiquettes sur l'ensemble de test
    y_pred = model.predict(X_test)

    # Calculer la précision du modèle
    accuracy = accuracy_score(y_test, y_pred)

    return (accuracy, y_pred)

# %% [markdown]
# # 1. Random Forest Classifier

# %%
import pandas as pd
import os
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from collections import Counter
import numpy as np
from scipy import stats

# Chemin vers le répertoire contenant les dossiers de données sur Google Drive
data_directory = "/content/gdrive/MyDrive/ListenToTheWild/vggish_cross_val_par_site_jours_commun"

# Liste des dossiers dans le répertoire
directories = sorted(os.listdir(data_directory))

# Initialisation du dictionnaire
main_dico = {}
for key in directories:
    main_dico[key] = {
        'list_acc': [],
        'mean_acc': 0,
        'mean_confidence_interval': (0, 0),
        'top_5_features_lists': [],
        'local_top_5_features': [],
        'conf_mat': np.array([]),
        'title_conf_mat': None
    }
# Boucle sur chaque dossier
for directory in directories:
  # Chemin vers le dossier contenant les sous-dossiers de données sur Google Drive
  sub_data_directory = "/content/gdrive/MyDrive/ListenToTheWild/vggish_cross_val_par_site_jours_commun/"+directory

  # Liste des sous-dossiers dans le dossier
  sub_directories = sorted(os.listdir(sub_data_directory), key=lambda x: int(x.split('_')[1]))

  # Boucle sur chaque sous-dossier
  for sub_directory in sub_directories:
    # Chemin vers le sous-dossier contenant les fichiers de train/test
    sub_directory_path = os.path.join(sub_data_directory, sub_directory)

    # Charger les données d'entraînement
    train_data = pd.read_csv(os.path.join(sub_directory_path, f"{directory}_{sub_directory}_train.csv"))
    # Ajouter les labels
    train_data_with_labels = add_labels(train_data)
    # Supprimer les colonnes "station_name" et "file_name"
    train_data_with_labels = train_data_with_labels.drop(['station_name', 'file_name'], axis=1)
    # Créer X et y
    X_train = train_data_with_labels.drop(columns=['label'])  # attributs
    y_train = train_data_with_labels['label']  # étiquettes

    # Charger les données de test
    test_data = pd.read_csv(os.path.join(sub_directory_path, f"{directory}_{sub_directory}_test.csv"))
    # Ajouter les labels
    test_data_with_labels = add_labels(test_data)
    # Supprimer les colonnes "station_name" et "file_name"
    test_data_with_labels = test_data_with_labels.drop(['station_name', 'file_name'], axis=1)
    # Créer X et y
    X_test = test_data_with_labels.drop(columns=['label'])  # attributs
    y_test = test_data_with_labels['label']  # étiquettes

    # Créer le modèle
    rf_model = RandomForestClassifier()

    # Entraîner sur l'ensemble de train et prédire sur l'ensemble de test
    rf_accuracy, rf_y_pred = train_and_predict(rf_model, X_train, y_train, X_test, y_test)

    # Ajouter la valeur de la précision au main_dico
    main_dico[directory]['list_acc'].append(rf_accuracy)

    # Créer series contenant les importances des features du modèle et les noms des features à partir des données d'entraînement
    rf_feature_importances = pd.Series(rf_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

    # Ajouter le top 5 des features au main_dico
    top_5_features = rf_feature_importances.head(5)
    list_top_5_features = top_5_features.index.tolist()
    main_dico[directory]['top_5_features_lists'].append(list_top_5_features)

    # Calculer une matrice de confusion par station (si toutes les classes)
    train_classes = list(rf_model.classes_)
    test_classes = list(set(y_test))
    if main_dico[directory]['conf_mat'].size == 0 and train_classes == test_classes:
      main_dico[directory]['conf_mat'] = confusion_matrix(y_test, rf_y_pred, labels=rf_model.classes_)
      main_dico[directory]['title_conf_mat'] = f"{directory} : {sub_directory} : Test"

  # Calculer la moyenne des précisions pour le site "directory"
  sample_data = main_dico[directory]['list_acc']
  sample_mean = np.mean(sample_data)
  main_dico[directory]['mean_acc'] = sample_mean

  # Calculer l'intervalle de confiance de la moyenne pour le site "directory"
  # (Intervalle de confiance t de Student car moins de 30 échantillons)
  sample_std = np.std(sample_data, ddof=1)  # ddof=1 pour utiliser la formule non biaisée de l'écart-type
  n = len(sample_data)
  confidence_level = 0.95
  degrees_of_freedom = n - 1
  t_critical = stats.t.ppf((1 + confidence_level) / 2, degrees_of_freedom)
  margin_of_error = t_critical * (sample_std / np.sqrt(n))
  main_dico[directory]['mean_confidence_interval'] = (sample_mean - margin_of_error, sample_mean + margin_of_error)

  # Calculer le top 5 local (pour le site "directory") des features
  all_features = [feature for sublist in main_dico[directory]['top_5_features_lists'] for feature in sublist]
  feature_counter = Counter(all_features)
  top_5_features_tuples = feature_counter.most_common(5)
  top_5_features_names = []
  for feature_tuple in top_5_features_tuples:
    top_5_features_names.append(feature_tuple[0])
  main_dico[directory]['local_top_5_features'] = top_5_features_names

  # Affichage des différents résultats
  print(f"Dossier {directory} ({len(sub_directories)} cross validation) :")
  print()
  print("Random Forest Classifier :")
  rounded_list = [round(x, 2) for x in main_dico[directory]['list_acc']]
  print(f"- Précisions sur les ensembles de test : {rounded_list}")
  print(f"- Moyenne des précisions : {round(main_dico[directory]['mean_acc'], 2)}")
  rounded_confidence_interval = tuple(round(value, 2) for value in main_dico[directory]['mean_confidence_interval'])
  print(f"- Intervalle de confiance (à {int(confidence_level*100)}%) : [{rounded_confidence_interval[0]}, {rounded_confidence_interval[1]}]")
  print(f"- Top 5 local des features : {main_dico[directory]['local_top_5_features']}")

  print()

  # Affichage de la matrice de confusion
  if main_dico[directory]['conf_mat'].size != 0:
    ConfusionMatrixDisplay(main_dico[directory]['conf_mat'], display_labels=rf_model.classes_).plot();
    plt.title(main_dico[directory]['title_conf_mat'])
    plt.show()
  else:
    print("Pas de matrice de confusion présentant toutes les classes.")

  print()
  print("=======================================================================================================================================================")
  print()

# Calculer la moyenne globale des précisions sur tous les sites
global_list_acc = []
for key, value in main_dico.items():
    global_list_acc.append(value['mean_acc'])
global_mean_acc = np.mean(global_list_acc)

# Calculer l'intervalle de confiance de la moyenne globale
# (Intervalle de confiance z car plus de 30 échantillons)
sample_mean = global_mean_acc
sample_std = np.std(global_list_acc, ddof=1)  # ddof=1 pour utiliser la formule non biaisée de l'écart-type
n = len(global_list_acc)
confidence_level = 0.95
z_critical = stats.norm.ppf((1 + confidence_level) / 2)
margin_of_error = z_critical * (sample_std / np.sqrt(n))
global_confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

# Calculer le top 5 global des features
global_top_5_features_lists = []
for key, value in main_dico.items():
    global_top_5_features_lists.append(value['local_top_5_features'])
all_features = [feature for sublist in global_top_5_features_lists for feature in sublist]
feature_counter = Counter(all_features)
global_top_5_features = feature_counter.most_common(5)

# Affichage des différents résultats
print(f"GLOBAL ({len(directories)} stations) :")
print()
print("Random Forest Classifier :")
print(f"- Moyenne globale des précisions : {round(global_mean_acc, 2)}")
rounded_global_confidence_interval = tuple(round(value, 2) for value in global_confidence_interval)
print(f"- Intervalle de confiance global (à {int(confidence_level*100)}%) : [{rounded_global_confidence_interval[0]}, {rounded_global_confidence_interval[1]}]")
print(f"- Top 5 global des features : {global_top_5_features}")
# Out:
# Dossier 2022_Ascou_Pailheres (4 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.85, 0.71, 0.81, 0.76]
# - Moyenne des précisions : 0.78
# - Intervalle de confiance (à 95%) : [0.68, 0.88]
# - Top 5 local des features : ['V76', 'V19', 'V16', 'V23', 'V22']
# =======================================================================================================================================================
#
# Dossier 2022_Bestiac_Trimouns (5 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.89, 0.82, 0.83, 0.84, 0.83]
# - Moyenne des précisions : 0.84
# - Intervalle de confiance (à 95%) : [0.81, 0.88]
# - Top 5 local des features : ['V37', 'V49', 'V40', 'V34', 'V52']
# =======================================================================================================================================================
#
# Dossier 2022_Bethmale_Eychelle (4 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.67, 0.81, 0.9, 0.88]
# - Moyenne des précisions : 0.81
# - Intervalle de confiance (à 95%) : [0.65, 0.98]
# - Top 5 local des features : ['V12', 'V19', 'V20', 'V49', 'V80']
# =======================================================================================================================================================
#
# Dossier 2022_Bonac_Orle (8 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.93, 0.88, 0.79, 0.93, 0.91, 0.91, 0.9, 0.97]
# - Moyenne des précisions : 0.9
# - Intervalle de confiance (à 95%) : [0.85, 0.94]
# - Top 5 local des features : ['V24', 'V9', 'V72', 'V90', 'V128']
# =======================================================================================================================================================
#
# Dossier 2022_Goulier_Val_de_Sos (4 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.69, 0.64, 0.81, 0.99]
# - Moyenne des précisions : 0.78
# - Intervalle de confiance (à 95%) : [0.54, 1.03]
# - Top 5 local des features : ['V15', 'V39', 'V66', 'V42', 'V4']
# =======================================================================================================================================================
#
# Dossier 2022_Mijanes_Estagnet (7 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.88, 0.82, 0.72, 0.66, 0.76, 0.66, 0.64]
# - Moyenne des précisions : 0.74
# - Intervalle de confiance (à 95%) : [0.65, 0.82]
# - Top 5 local des features : ['V26', 'V87', 'V56', 'V29', 'V54']
# =======================================================================================================================================================
#
# Dossier 2022_Mijanes_Trabesses (5 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.65, 0.7, 0.75, 0.74, 0.75]
# - Moyenne des précisions : 0.72
# - Intervalle de confiance (à 95%) : [0.67, 0.77]
# - Top 5 local des features : ['V20', 'V63', 'V49', 'V43', 'V71']
# =======================================================================================================================================================
#
# Dossier 2022_Montségur_Soularac (9 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.8, 0.91, 0.88, 0.91, 0.92, 0.88, 0.9, 0.84, 0.84]
# - Moyenne des précisions : 0.88
# - Intervalle de confiance (à 95%) : [0.85, 0.91]
# - Top 5 local des features : ['V40', 'V19', 'V36', 'V23', 'V3']
# =======================================================================================================================================================
#
# Dossier 2022_Seix_Col_de_Pause (4 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.97, 0.94, 0.92, 0.89]
# - Moyenne des précisions : 0.93
# - Intervalle de confiance (à 95%) : [0.87, 0.99]
# - Top 5 local des features : ['V12', 'V22', 'V32', 'V29', 'V6']
# =======================================================================================================================================================
#
# Dossier 2022_Sentein_Eylie (7 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.9, 0.93, 0.88, 0.69, 0.9, 0.82, 0.85]
# - Moyenne des précisions : 0.85
# - Intervalle de confiance (à 95%) : [0.78, 0.93]
# - Top 5 local des features : ['V39', 'V24', 'V4', 'V86', 'V30']
# =======================================================================================================================================================
#
# Dossier 2023_Appy_Etang_dAppy (8 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.84, 0.93, 0.94, 0.97, 0.79, 0.97, 0.95, 0.92]
# - Moyenne des précisions : 0.91
# - Intervalle de confiance (à 95%) : [0.86, 0.97]
# - Top 5 local des features : ['V124', 'V102', 'V112', 'V33', 'V76']
# =======================================================================================================================================================
#
# Dossier 2023_Arrien_Pic_Midi_Bordes (14 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.82, 0.85, 0.84, 0.78, 0.85, 0.89, 0.74, 0.79, 0.92, 0.88, 0.9, 0.86, 0.83, 0.89]
# - Moyenne des précisions : 0.85
# - Intervalle de confiance (à 95%) : [0.82, 0.88]
# - Top 5 local des features : ['V12', 'V30', 'V1', 'V49', 'V32']
# =======================================================================================================================================================
#
# Dossier 2023_Aston_Plateau_de_Beille (7 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.98, 0.86, 0.92, 0.93, 0.81, 0.9, 0.92]
# - Moyenne des précisions : 0.9
# - Intervalle de confiance (à 95%) : [0.85, 0.95]
# - Top 5 local des features : ['V49', 'V12', 'V40', 'V11', 'V43']
# =======================================================================================================================================================
#
# Dossier 2023_Aulus_Turon_Rose (8 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.81, 0.76, 0.86, 0.93, 0.79, 0.82, 0.8, 0.78]
# - Moyenne des précisions : 0.82
# - Intervalle de confiance (à 95%) : [0.78, 0.86]
# - Top 5 local des features : ['V12', 'V24', 'V88', 'V34', 'V62']
# =======================================================================================================================================================
#
# Dossier 2023_Bonac_Arech (9 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.66, 0.83, 0.85, 0.9, 0.8, 0.84, 0.91, 0.82, 0.77]
# - Moyenne des précisions : 0.82
# - Intervalle de confiance (à 95%) : [0.76, 0.88]
# - Top 5 local des features : ['V30', 'V85', 'V109', 'V42', 'V38']
# =======================================================================================================================================================
#
# Dossier 2023_Couflens_Pouill (4 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.76, 0.89, 0.86, 0.96]
# - Moyenne des précisions : 0.87
# - Intervalle de confiance (à 95%) : [0.74, 1.0]
# - Top 5 local des features : ['V45', 'V9', 'V122', 'V26', 'V22']
# =======================================================================================================================================================
#
# Dossier 2023_Formiguères_Serra_dels_Alarbs (14 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.65, 0.84, 0.85, 0.89, 0.9, 0.82, 0.7, 0.8, 0.64, 0.77, 0.78, 0.86, 0.65, 0.7]
# - Moyenne des précisions : 0.78
# - Intervalle de confiance (à 95%) : [0.72, 0.83]
# - Top 5 local des features : ['V87', 'V49', 'V26', 'V24', 'V34']
# =======================================================================================================================================================
#
# Dossier 2023_Gestiès_Le_Clot (8 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.94, 0.9, 0.86, 0.96, 0.91, 0.9, 0.82, 0.88]
# - Moyenne des précisions : 0.9
# - Intervalle de confiance (à 95%) : [0.86, 0.93]
# - Top 5 local des features : ['V62', 'V108', 'V87', 'V78', 'V36']
# =======================================================================================================================================================
#
# Dossier 2023_Les_Angles_Puig_del_Pam (16 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.58, 0.64, 0.58, 0.64, 0.59, 0.68, 0.74, 0.69, 0.89, 0.78, 0.84, 0.91, 0.91, 0.79, 0.75, 0.79]
# - Moyenne des précisions : 0.74
# - Intervalle de confiance (à 95%) : [0.68, 0.8]
# - Top 5 local des features : ['V24', 'V49', 'V40', 'V8', 'V80']
# =======================================================================================================================================================
#
# Dossier 2023_Les_Angles_Roc_dAude (14 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.56, 0.46, 0.57, 0.75, 0.78, 0.7, 0.57, 0.52, 0.77, 0.71, 0.81, 0.8, 0.74, 0.86]
# - Moyenne des précisions : 0.69
# - Intervalle de confiance (à 95%) : [0.61, 0.76]
# - Top 5 local des features : ['V29', 'V26', 'V19', 'V5', 'V24']
# =======================================================================================================================================================
#
# Dossier 2023_Miglos_Pla_de_Montcamp (7 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.78, 0.83, 0.84, 0.73, 0.83, 0.81, 0.81]
# - Moyenne des précisions : 0.81
# - Intervalle de confiance (à 95%) : [0.77, 0.84]
# - Top 5 local des features : ['V19', 'V106', 'V36', 'V87', 'V10']
# =======================================================================================================================================================
#
# Dossier 2023_Montferrier_Mont_dOlmes (7 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.81, 0.89, 0.75, 0.68, 0.76, 0.65, 0.92]
# - Moyenne des précisions : 0.78
# - Intervalle de confiance (à 95%) : [0.69, 0.88]
# - Top 5 local des features : ['V15', 'V77', 'V88', 'V24', 'V3']
# =======================================================================================================================================================
#
# Dossier 2023_Seix_Pic_de_Montbuou (13 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.95, 0.97, 0.97, 0.99, 0.95, 0.98, 0.98, 0.96, 0.92, 0.96, 0.95, 0.94, 0.92]
# - Moyenne des précisions : 0.96
# - Intervalle de confiance (à 95%) : [0.94, 0.97]
# - Top 5 local des features : ['V16', 'V20', 'V7', 'V9', 'V19']
# =======================================================================================================================================================
#
# Dossier 2023_Ustou_Col_dEscots (14 cross validation) :
#
# Random Forest Classifier :
# - Précisions sur les ensembles de test : [0.92, 0.99, 0.99, 0.96, 0.99, 0.97, 0.99, 1.0, 0.97, 0.98, 0.95, 0.93, 0.94, 0.96]
# - Moyenne des précisions : 0.97
# - Intervalle de confiance (à 95%) : [0.95, 0.98]
# - Top 5 local des features : ['V29', 'V49', 'V20', 'V103', 'V43']
# =======================================================================================================================================================
#
# GLOBAL (24 stations) :
#
# Random Forest Classifier :
# - Moyenne globale des précisions : 0.83
# - Intervalle de confiance global (à 95%) : [0.8, 0.86]
# - Top 5 global des features : [('V49', 8), ('V24', 7), ('V19', 6), ('V12', 5), ('V40', 4)]

# %% [markdown]
# # 2. MLP Classifier

# %%
import pandas as pd
import os
from sklearn.neural_network import MLPClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from collections import Counter
import numpy as np
from scipy import stats

# Chemin vers le répertoire contenant les dossiers de données sur Google Drive
data_directory = "/content/gdrive/MyDrive/ListenToTheWild/vggish_cross_val_par_site_jours_commun"

# Liste des dossiers dans le répertoire
directories = sorted(os.listdir(data_directory))

# Initialisation du dictionnaire
main_dico = {}
for key in directories:
    main_dico[key] = {
        'list_acc': [],
        'mean_acc': 0,
        'mean_confidence_interval': (0, 0),
        'top_5_features_lists': [],
        'local_top_5_features': [],
        'conf_mat': np.array([]),
        'title_conf_mat': None
    }
# Boucle sur chaque dossier
for directory in directories:
  # Chemin vers le dossier contenant les sous-dossiers de données sur Google Drive
  sub_data_directory = "/content/gdrive/MyDrive/ListenToTheWild/vggish_cross_val_par_site_jours_commun/"+directory

  # Liste des sous-dossiers dans le dossier
  sub_directories = sorted(os.listdir(sub_data_directory), key=lambda x: int(x.split('_')[1]))

  # Boucle sur chaque sous-dossier
  for sub_directory in sub_directories:
    # Chemin vers le sous-dossier contenant les fichiers de train/test
    sub_directory_path = os.path.join(sub_data_directory, sub_directory)

    # Charger les données d'entraînement
    train_data = pd.read_csv(os.path.join(sub_directory_path, f"{directory}_{sub_directory}_train.csv"))
    # Ajouter les labels
    train_data_with_labels = add_labels(train_data)
    # Supprimer les colonnes "station_name" et "file_name"
    train_data_with_labels = train_data_with_labels.drop(['station_name', 'file_name'], axis=1)
    # Créer X et y
    X_train = train_data_with_labels.drop(columns=['label'])  # attributs
    y_train = train_data_with_labels['label']  # étiquettes

    # Charger les données de test
    test_data = pd.read_csv(os.path.join(sub_directory_path, f"{directory}_{sub_directory}_test.csv"))
    # Ajouter les labels
    test_data_with_labels = add_labels(test_data)
    # Supprimer les colonnes "station_name" et "file_name"
    test_data_with_labels = test_data_with_labels.drop(['station_name', 'file_name'], axis=1)
    # Créer X et y
    X_test = test_data_with_labels.drop(columns=['label'])  # attributs
    y_test = test_data_with_labels['label']  # étiquettes

    # Créer le modèle
    mlp_model = MLPClassifier()

    # Entraîner sur l'ensemble de train et prédire sur l'ensemble de test
    mlp_accuracy, mlp_y_pred = train_and_predict(mlp_model, X_train, y_train, X_test, y_test)

    # Ajouter la valeur de la précision au main_dico
    main_dico[directory]['list_acc'].append(mlp_accuracy)

    # Importances des features
    input_layer_weights = mlp_model.coefs_[0]
    feature_names = list(X_train.columns)
    feature_importance = np.sum(np.abs(input_layer_weights), axis=1)
    feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
    mlp_feature_importances = feature_importance_df.sort_values(by='Importance', ascending=False)

    # Ajouter le top 5 des features au main_dico
    top_5_features = mlp_feature_importances['Feature'].head(5)
    list_top_5_features = top_5_features.tolist()
    main_dico[directory]['top_5_features_lists'].append(list_top_5_features)

    # Calculer une matrice de confusion par station (si toutes les classes)
    train_classes = list(mlp_model.classes_)
    test_classes = list(set(y_test))
    if main_dico[directory]['conf_mat'].size == 0 and train_classes == test_classes:
      main_dico[directory]['conf_mat'] = confusion_matrix(y_test, mlp_y_pred, labels=mlp_model.classes_)
      main_dico[directory]['title_conf_mat'] = f"{directory} : {sub_directory} : Test"

  # Calculer la moyenne des précisions pour le site "directory"
  sample_data = main_dico[directory]['list_acc']
  sample_mean = np.mean(sample_data)
  main_dico[directory]['mean_acc'] = sample_mean

  # Calculer l'intervalle de confiance de la moyenne pour le site "directory"
  # (Intervalle de confiance t de Student car moins de 30 échantillons)
  sample_std = np.std(sample_data, ddof=1)  # ddof=1 pour utiliser la formule non biaisée de l'écart-type
  n = len(sample_data)
  confidence_level = 0.95
  degrees_of_freedom = n - 1
  t_critical = stats.t.ppf((1 + confidence_level) / 2, degrees_of_freedom)
  margin_of_error = t_critical * (sample_std / np.sqrt(n))
  main_dico[directory]['mean_confidence_interval'] = (sample_mean - margin_of_error, sample_mean + margin_of_error)

  # Calculer le top 5 local (pour le site "directory") des features
  all_features = [feature for sublist in main_dico[directory]['top_5_features_lists'] for feature in sublist]
  feature_counter = Counter(all_features)
  top_5_features_tuples = feature_counter.most_common(5)
  top_5_features_names = []
  for feature_tuple in top_5_features_tuples:
    top_5_features_names.append(feature_tuple[0])
  main_dico[directory]['local_top_5_features'] = top_5_features_names

  # Affichage des différents résultats
  print(f"Dossier {directory} ({len(sub_directories)} cross validation) :")
  print()
  print("MLP Classifier :")
  rounded_list = [round(x, 2) for x in main_dico[directory]['list_acc']]
  print(f"- Précisions sur les ensembles de test : {rounded_list}")
  print(f"- Moyenne des précisions : {round(main_dico[directory]['mean_acc'], 2)}")
  rounded_confidence_interval = tuple(round(value, 2) for value in main_dico[directory]['mean_confidence_interval'])
  print(f"- Intervalle de confiance (à {int(confidence_level*100)}%) : [{rounded_confidence_interval[0]}, {rounded_confidence_interval[1]}]")
  print(f"- Top 5 local des features : {main_dico[directory]['local_top_5_features']}")

  print()

  # Affichage de la matrice de confusion
  if main_dico[directory]['conf_mat'].size != 0:
    ConfusionMatrixDisplay(main_dico[directory]['conf_mat'], display_labels=mlp_model.classes_).plot();
    plt.title(main_dico[directory]['title_conf_mat'])
    plt.show()
  else:
    print("Pas de matrice de confusion présentant toutes les classes.")

  print()
  print("=======================================================================================================================================================")
  print()

# Calculer la moyenne globale des précisions sur tous les sites
global_list_acc = []
for key, value in main_dico.items():
    global_list_acc.append(value['mean_acc'])
global_mean_acc = np.mean(global_list_acc)

# Calculer l'intervalle de confiance de la moyenne globale
# (Intervalle de confiance z car plus de 30 échantillons)
sample_mean = global_mean_acc
sample_std = np.std(global_list_acc, ddof=1)  # ddof=1 pour utiliser la formule non biaisée de l'écart-type
n = len(global_list_acc)
confidence_level = 0.95
z_critical = stats.norm.ppf((1 + confidence_level) / 2)
margin_of_error = z_critical * (sample_std / np.sqrt(n))
global_confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

# Calculer le top 5 global des features
global_top_5_features_lists = []
for key, value in main_dico.items():
    global_top_5_features_lists.append(value['local_top_5_features'])
all_features = [feature for sublist in global_top_5_features_lists for feature in sublist]
feature_counter = Counter(all_features)
global_top_5_features = feature_counter.most_common(5)

# Affichage des différents résultats
print(f"GLOBAL ({len(directories)} stations) :")
print()
print("MLP Classifier :")
print(f"- Moyenne globale des précisions : {round(global_mean_acc, 2)}")
rounded_global_confidence_interval = tuple(round(value, 2) for value in global_confidence_interval)
print(f"- Intervalle de confiance global (à {int(confidence_level*100)}%) : [{rounded_global_confidence_interval[0]}, {rounded_global_confidence_interval[1]}]")
print(f"- Top 5 global des features : {global_top_5_features}")
# Out:
# Dossier 2022_Ascou_Pailheres (4 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.81, 0.68, 0.77, 0.71]
# - Moyenne des précisions : 0.74
# - Intervalle de confiance (à 95%) : [0.65, 0.83]
# - Top 5 local des features : ['V53', 'V16', 'V94', 'V89', 'V22']
# =======================================================================================================================================================
#
# Dossier 2022_Bestiac_Trimouns (5 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.77, 0.79, 0.81, 0.84, 0.83]
# - Moyenne des précisions : 0.81
# - Intervalle de confiance (à 95%) : [0.77, 0.85]
# - Top 5 local des features : ['V60', 'V24', 'V125', 'V80', 'V29']
# =======================================================================================================================================================
#
# Dossier 2022_Bethmale_Eychelle (4 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.66, 0.71, 0.82, 0.83]
# - Moyenne des précisions : 0.76
# - Intervalle de confiance (à 95%) : [0.62, 0.89]
# - Top 5 local des features : ['V19', 'V62', 'V119', 'V46', 'V68']
# =======================================================================================================================================================
#
# Dossier 2022_Bonac_Orle (8 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.91, 0.87, 0.71, 0.89, 0.91, 0.91, 0.84, 0.9]
# - Moyenne des précisions : 0.87
# - Intervalle de confiance (à 95%) : [0.81, 0.92]
# - Top 5 local des features : ['V51', 'V58', 'V91', 'V5', 'V105']
# =======================================================================================================================================================
#
# Dossier 2022_Goulier_Val_de_Sos (4 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.63, 0.6, 0.79, 0.76]
# - Moyenne des précisions : 0.69
# - Intervalle de confiance (à 95%) : [0.54, 0.84]
# - Top 5 local des features : ['V53', 'V38', 'V84', 'V106', 'V47']
# =======================================================================================================================================================
#
# Dossier 2022_Mijanes_Estagnet (7 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.8, 0.77, 0.73, 0.65, 0.63, 0.62, 0.6]
# - Moyenne des précisions : 0.69
# - Intervalle de confiance (à 95%) : [0.61, 0.76]
# - Top 5 local des features : ['V42', 'V116', 'V1', 'V102', 'V12']
# =======================================================================================================================================================
#
# Dossier 2022_Mijanes_Trabesses (5 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.58, 0.65, 0.74, 0.62, 0.6]
# - Moyenne des précisions : 0.64
# - Intervalle de confiance (à 95%) : [0.56, 0.72]
# - Top 5 local des features : ['V119', 'V9', 'V29', 'V93', 'V128']
# =======================================================================================================================================================
#
# Dossier 2022_Montségur_Soularac (9 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.83, 0.86, 0.85, 0.9, 0.86, 0.84, 0.84, 0.85, 0.81]
# - Moyenne des précisions : 0.85
# - Intervalle de confiance (à 95%) : [0.83, 0.87]
# - Top 5 local des features : ['V37', 'V36', 'V96', 'V101', 'V65']
# =======================================================================================================================================================
#
# Dossier 2022_Seix_Col_de_Pause (4 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.91, 0.91, 0.87, 0.9]
# - Moyenne des précisions : 0.9
# - Intervalle de confiance (à 95%) : [0.87, 0.93]
# - Top 5 local des features : ['V24', 'V58', 'V77', 'V12', 'V47']
# =======================================================================================================================================================
#
# Dossier 2022_Sentein_Eylie (7 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.87, 0.87, 0.83, 0.74, 0.84, 0.74, 0.85]
# - Moyenne des précisions : 0.82
# - Intervalle de confiance (à 95%) : [0.77, 0.87]
# - Top 5 local des features : ['V62', 'V79', 'V77', 'V5', 'V104']
# =======================================================================================================================================================
#
# Dossier 2023_Appy_Etang_dAppy (8 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.81, 0.8, 0.91, 0.93, 0.68, 0.85, 0.93, 0.86]
# - Moyenne des précisions : 0.85
# - Intervalle de confiance (à 95%) : [0.78, 0.92]
# - Top 5 local des features : ['V1', 'V59', 'V104', 'V48', 'V33']
# =======================================================================================================================================================
#
# Dossier 2023_Arrien_Pic_Midi_Bordes (14 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.78, 0.82, 0.82, 0.79, 0.79, 0.88, 0.7, 0.75, 0.83, 0.87, 0.8, 0.85, 0.81, 0.78]
# - Moyenne des précisions : 0.81
# - Intervalle de confiance (à 95%) : [0.78, 0.83]
# - Top 5 local des features : ['V77', 'V67', 'V100', 'V69', 'V31']
# =======================================================================================================================================================
#
# Dossier 2023_Aston_Plateau_de_Beille (7 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.93, 0.9, 0.88, 0.83, 0.83, 0.79, 0.89]
# - Moyenne des précisions : 0.86
# - Intervalle de confiance (à 95%) : [0.82, 0.91]
# - Top 5 local des features : ['V109', 'V19', 'V8', 'V59', 'V9']
# =======================================================================================================================================================
#
# Dossier 2023_Aulus_Turon_Rose (8 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.88, 0.78, 0.81, 0.9, 0.75, 0.72, 0.79, 0.76]
# - Moyenne des précisions : 0.8
# - Intervalle de confiance (à 95%) : [0.75, 0.85]
# - Top 5 local des features : ['V26', 'V37', 'V110', 'V73', 'V74']
# =======================================================================================================================================================
#
# Dossier 2023_Bonac_Arech (9 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.62, 0.78, 0.8, 0.86, 0.85, 0.79, 0.79, 0.73, 0.67]
# - Moyenne des précisions : 0.77
# - Intervalle de confiance (à 95%) : [0.7, 0.83]
# - Top 5 local des features : ['V41', 'V60', 'V45', 'V119', 'V12']
# =======================================================================================================================================================
#
# Dossier 2023_Couflens_Pouill (4 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.76, 0.82, 0.84, 0.88]
# - Moyenne des précisions : 0.83
# - Intervalle de confiance (à 95%) : [0.75, 0.91]
# - Top 5 local des features : ['V35', 'V50', 'V55', 'V80', 'V42']
# =======================================================================================================================================================
#
# Dossier 2023_Formiguères_Serra_dels_Alarbs (14 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.6, 0.72, 0.79, 0.82, 0.85, 0.77, 0.74, 0.76, 0.59, 0.73, 0.79, 0.88, 0.71, 0.64]
# - Moyenne des précisions : 0.74
# - Intervalle de confiance (à 95%) : [0.69, 0.79]
# - Top 5 local des features : ['V79', 'V6', 'V64', 'V16', 'V45']
# =======================================================================================================================================================
#
# Dossier 2023_Gestiès_Le_Clot (8 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.83, 0.84, 0.88, 0.88, 0.85, 0.83, 0.78, 0.82]
# - Moyenne des précisions : 0.84
# - Intervalle de confiance (à 95%) : [0.81, 0.86]
# - Top 5 local des features : ['V14', 'V108', 'V88', 'V87', 'V128']
# =======================================================================================================================================================
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Dossier 2023_Les_Angles_Puig_del_Pam (16 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.78, 0.67, 0.55, 0.61, 0.59, 0.62, 0.73, 0.73, 0.82, 0.79, 0.71, 0.82, 0.76, 0.78, 0.77, 0.68]
# - Moyenne des précisions : 0.71
# - Intervalle de confiance (à 95%) : [0.67, 0.76]
# - Top 5 local des features : ['V23', 'V105', 'V4', 'V124', 'V51']
# =======================================================================================================================================================
#
# Dossier 2023_Les_Angles_Roc_dAude (14 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.56, 0.52, 0.48, 0.73, 0.76, 0.66, 0.56, 0.53, 0.65, 0.69, 0.72, 0.76, 0.77, 0.75]
# - Moyenne des précisions : 0.65
# - Intervalle de confiance (à 95%) : [0.59, 0.71]
# - Top 5 local des features : ['V68', 'V53', 'V38', 'V11', 'V88']
# =======================================================================================================================================================
#
# Dossier 2023_Miglos_Pla_de_Montcamp (7 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.65, 0.75, 0.79, 0.78, 0.79, 0.79, 0.74]
# - Moyenne des précisions : 0.76
# - Intervalle de confiance (à 95%) : [0.71, 0.8]
# - Top 5 local des features : ['V19', 'V17', 'V67', 'V103', 'V100']
# =======================================================================================================================================================
#
# Dossier 2023_Montferrier_Mont_dOlmes (7 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.81, 0.66, 0.77, 0.59, 0.62, 0.67, 0.82]
# - Moyenne des précisions : 0.71
# - Intervalle de confiance (à 95%) : [0.62, 0.79]
# - Top 5 local des features : ['V16', 'V110', 'V65', 'V66', 'V123']
# =======================================================================================================================================================
#
# Dossier 2023_Seix_Pic_de_Montbuou (13 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.88, 0.93, 0.97, 0.88, 0.93, 0.98, 0.96, 0.96, 0.93, 0.92, 0.86, 0.91, 0.92]
# - Moyenne des précisions : 0.92
# - Intervalle de confiance (à 95%) : [0.9, 0.95]
# - Top 5 local des features : ['V60', 'V12', 'V46', 'V70', 'V57']
# =======================================================================================================================================================
#
# Dossier 2023_Ustou_Col_dEscots (14 cross validation) :
#
# MLP Classifier :
# - Précisions sur les ensembles de test : [0.85, 0.99, 0.99, 0.97, 0.97, 0.97, 0.99, 0.95, 0.97, 0.96, 0.92, 0.9, 0.93, 0.94]
# - Moyenne des précisions : 0.95
# - Intervalle de confiance (à 95%) : [0.93, 0.97]
# - Top 5 local des features : ['V10', 'V62', 'V50', 'V121', 'V98']
# =======================================================================================================================================================
#
# GLOBAL (24 stations) :
#
# MLP Classifier :
# - Moyenne globale des précisions : 0.79
# - Intervalle de confiance global (à 95%) : [0.76, 0.82]
# - Top 5 global des features : [('V12', 4), ('V53', 3), ('V16', 3), ('V60', 3), ('V19', 3)]

# %% [markdown]
# # 3. Gradient Boosting Classifier

# %%
import pandas as pd
import os
from sklearn.ensemble import GradientBoostingClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from collections import Counter
import numpy as np
from scipy import stats

# Chemin vers le répertoire contenant les dossiers de données sur Google Drive
data_directory = "/content/gdrive/MyDrive/ListenToTheWild/vggish_cross_val_par_site_jours_commun"

# Liste des dossiers dans le répertoire
directories = sorted(os.listdir(data_directory))

# Initialisation du dictionnaire
main_dico = {}
for key in directories:
    main_dico[key] = {
        'list_acc': [],
        'mean_acc': 0,
        'mean_confidence_interval': (0, 0),
        'top_5_features_lists': [],
        'local_top_5_features': [],
        'conf_mat': np.array([]),
        'title_conf_mat': None
    }
# Boucle sur chaque dossier
for directory in directories:
  # Chemin vers le dossier contenant les sous-dossiers de données sur Google Drive
  sub_data_directory = "/content/gdrive/MyDrive/ListenToTheWild/vggish_cross_val_par_site_jours_commun/"+directory

  # Liste des sous-dossiers dans le dossier
  sub_directories = sorted(os.listdir(sub_data_directory), key=lambda x: int(x.split('_')[1]))

  # Boucle sur chaque sous-dossier
  for sub_directory in sub_directories:
    # Chemin vers le sous-dossier contenant les fichiers de train/test
    sub_directory_path = os.path.join(sub_data_directory, sub_directory)

    # Charger les données d'entraînement
    train_data = pd.read_csv(os.path.join(sub_directory_path, f"{directory}_{sub_directory}_train.csv"))
    # Ajouter les labels
    train_data_with_labels = add_labels(train_data)
    # Supprimer les colonnes "station_name" et "file_name"
    train_data_with_labels = train_data_with_labels.drop(['station_name', 'file_name'], axis=1)
    # Créer X et y
    X_train = train_data_with_labels.drop(columns=['label'])  # attributs
    y_train = train_data_with_labels['label']  # étiquettes

    # Charger les données de test
    test_data = pd.read_csv(os.path.join(sub_directory_path, f"{directory}_{sub_directory}_test.csv"))
    # Ajouter les labels
    test_data_with_labels = add_labels(test_data)
    # Supprimer les colonnes "station_name" et "file_name"
    test_data_with_labels = test_data_with_labels.drop(['station_name', 'file_name'], axis=1)
    # Créer X et y
    X_test = test_data_with_labels.drop(columns=['label'])  # attributs
    y_test = test_data_with_labels['label']  # étiquettes

    # Créer le modèle
    gb_model = GradientBoostingClassifier()

    # Entraîner sur l'ensemble de train et prédire sur l'ensemble de test
    gb_accuracy, gb_y_pred = train_and_predict(gb_model, X_train, y_train, X_test, y_test)

    # Ajouter la valeur de la précision au main_dico
    main_dico[directory]['list_acc'].append(gb_accuracy)

    # Créer series contenant les importances des features du modèle et les noms des features à partir des données d'entraînement
    gb_feature_importances = pd.Series(gb_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

    # Ajouter le top 5 des features au main_dico
    top_5_features = gb_feature_importances.head(5)
    list_top_5_features = top_5_features.index.tolist()
    main_dico[directory]['top_5_features_lists'].append(list_top_5_features)

    # Calculer une matrice de confusion par station (si toutes les classes)
    train_classes = list(gb_model.classes_)
    test_classes = list(set(y_test))
    if main_dico[directory]['conf_mat'].size == 0 and train_classes == test_classes:
      main_dico[directory]['conf_mat'] = confusion_matrix(y_test, gb_y_pred, labels=gb_model.classes_)
      main_dico[directory]['title_conf_mat'] = f"{directory} : {sub_directory} : Test"

  # Calculer la moyenne des précisions pour le site "directory"
  sample_data = main_dico[directory]['list_acc']
  sample_mean = np.mean(sample_data)
  main_dico[directory]['mean_acc'] = sample_mean

  # Calculer l'intervalle de confiance de la moyenne pour le site "directory"
  # (Intervalle de confiance t de Student car moins de 30 échantillons)
  sample_std = np.std(sample_data, ddof=1)  # ddof=1 pour utiliser la formule non biaisée de l'écart-type
  n = len(sample_data)
  confidence_level = 0.95
  degrees_of_freedom = n - 1
  t_critical = stats.t.ppf((1 + confidence_level) / 2, degrees_of_freedom)
  margin_of_error = t_critical * (sample_std / np.sqrt(n))
  main_dico[directory]['mean_confidence_interval'] = (sample_mean - margin_of_error, sample_mean + margin_of_error)

  # Calculer le top 5 local (pour le site "directory") des features
  all_features = [feature for sublist in main_dico[directory]['top_5_features_lists'] for feature in sublist]
  feature_counter = Counter(all_features)
  top_5_features_tuples = feature_counter.most_common(5)
  top_5_features_names = []
  for feature_tuple in top_5_features_tuples:
    top_5_features_names.append(feature_tuple[0])
  main_dico[directory]['local_top_5_features'] = top_5_features_names

  # Affichage des différents résultats
  print(f"Dossier {directory} ({len(sub_directories)} cross validation) :")
  print()
  print("Gradient Boosting Classifier :")
  rounded_list = [round(x, 2) for x in main_dico[directory]['list_acc']]
  print(f"- Précisions sur les ensembles de test : {rounded_list}")
  print(f"- Moyenne des précisions : {round(main_dico[directory]['mean_acc'], 2)}")
  rounded_confidence_interval = tuple(round(value, 2) for value in main_dico[directory]['mean_confidence_interval'])
  print(f"- Intervalle de confiance (à {int(confidence_level*100)}%) : [{rounded_confidence_interval[0]}, {rounded_confidence_interval[1]}]")
  print(f"- Top 5 local des features : {main_dico[directory]['local_top_5_features']}")

  print()

  # Affichage de la matrice de confusion
  if main_dico[directory]['conf_mat'].size != 0:
    ConfusionMatrixDisplay(main_dico[directory]['conf_mat'], display_labels=gb_model.classes_).plot();
    plt.title(main_dico[directory]['title_conf_mat'])
    plt.show()
  else:
    print("Pas de matrice de confusion présentant toutes les classes.")

  print()
  print("=======================================================================================================================================================")
  print()

# Calculer la moyenne globale des précisions sur tous les sites
global_list_acc = []
for key, value in main_dico.items():
    global_list_acc.append(value['mean_acc'])
global_mean_acc = np.mean(global_list_acc)

# Calculer l'intervalle de confiance de la moyenne globale
# (Intervalle de confiance z car plus de 30 échantillons)
sample_mean = global_mean_acc
sample_std = np.std(global_list_acc, ddof=1)  # ddof=1 pour utiliser la formule non biaisée de l'écart-type
n = len(global_list_acc)
confidence_level = 0.95
z_critical = stats.norm.ppf((1 + confidence_level) / 2)
margin_of_error = z_critical * (sample_std / np.sqrt(n))
global_confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

# Calculer le top 5 global des features
global_top_5_features_lists = []
for key, value in main_dico.items():
    global_top_5_features_lists.append(value['local_top_5_features'])
all_features = [feature for sublist in global_top_5_features_lists for feature in sublist]
feature_counter = Counter(all_features)
global_top_5_features = feature_counter.most_common(5)

# Affichage des différents résultats
print(f"GLOBAL ({len(directories)} stations) :")
print()
print("Gradient Boosting Classifier :")
print(f"- Moyenne globale des précisions : {round(global_mean_acc, 2)}")
rounded_global_confidence_interval = tuple(round(value, 2) for value in global_confidence_interval)
print(f"- Intervalle de confiance global (à {int(confidence_level*100)}%) : [{rounded_global_confidence_interval[0]}, {rounded_global_confidence_interval[1]}]")
print(f"- Top 5 global des features : {global_top_5_features}")
# Out:
# Dossier 2022_Ascou_Pailheres (4 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.88, 0.7, 0.76, 0.76]
# - Moyenne des précisions : 0.78
# - Intervalle de confiance (à 95%) : [0.66, 0.89]
# - Top 5 local des features : ['V76', 'V23', 'V42', 'V22', 'V15']
# =======================================================================================================================================================
#
# Dossier 2022_Bestiac_Trimouns (5 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.89, 0.79, 0.86, 0.85, 0.83]
# - Moyenne des précisions : 0.85
# - Intervalle de confiance (à 95%) : [0.8, 0.89]
# - Top 5 local des features : ['V37', 'V19', 'V49', 'V98', 'V12']
# =======================================================================================================================================================
#
# Dossier 2022_Bethmale_Eychelle (4 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.77, 0.82, 0.88, 0.88]
# - Moyenne des précisions : 0.84
# - Intervalle de confiance (à 95%) : [0.76, 0.92]
# - Top 5 local des features : ['V19', 'V20', 'V12', 'V34', 'V70']
# =======================================================================================================================================================
#
# Dossier 2022_Bonac_Orle (8 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.93, 0.9, 0.79, 0.96, 0.92, 0.92, 0.9, 0.93]
# - Moyenne des précisions : 0.9
# - Intervalle de confiance (à 95%) : [0.86, 0.95]
# - Top 5 local des features : ['V24', 'V9', 'V128', 'V90', 'V72']
# =======================================================================================================================================================
#
# Dossier 2022_Goulier_Val_de_Sos (4 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.77, 0.64, 0.8, 0.92]
# - Moyenne des précisions : 0.78
# - Intervalle de confiance (à 95%) : [0.6, 0.97]
# - Top 5 local des features : ['V28', 'V15', 'V42', 'V33', 'V71']
# =======================================================================================================================================================
#
# Dossier 2022_Mijanes_Estagnet (7 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.88, 0.83, 0.69, 0.72, 0.75, 0.7, 0.64]
# - Moyenne des précisions : 0.75
# - Intervalle de confiance (à 95%) : [0.67, 0.82]
# - Top 5 local des features : ['V26', 'V29', 'V56', 'V68', 'V54']
# =======================================================================================================================================================
#
# Dossier 2022_Mijanes_Trabesses (5 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.6, 0.68, 0.77, 0.74, 0.74]
# - Moyenne des précisions : 0.7
# - Intervalle de confiance (à 95%) : [0.62, 0.79]
# - Top 5 local des features : ['V20', 'V63', 'V71', 'V110', 'V49']
# =======================================================================================================================================================
#
# Dossier 2022_Montségur_Soularac (9 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.8, 0.92, 0.86, 0.91, 0.93, 0.9, 0.89, 0.84, 0.8]
# - Moyenne des précisions : 0.87
# - Intervalle de confiance (à 95%) : [0.84, 0.91]
# - Top 5 local des features : ['V19', 'V4', 'V95', 'V45', 'V3']
# =======================================================================================================================================================
#
# Dossier 2022_Seix_Col_de_Pause (4 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.99, 0.94, 0.92, 0.84]
# - Moyenne des précisions : 0.92
# - Intervalle de confiance (à 95%) : [0.82, 1.02]
# - Top 5 local des features : ['V22', 'V32', 'V12', 'V6', 'V2']
# =======================================================================================================================================================
#
# Dossier 2022_Sentein_Eylie (7 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.9, 0.92, 0.88, 0.75, 0.92, 0.79, 0.88]
# - Moyenne des précisions : 0.86
# - Intervalle de confiance (à 95%) : [0.8, 0.92]
# - Top 5 local des features : ['V24', 'V39', 'V16', 'V86', 'V19']
# =======================================================================================================================================================
#
# Dossier 2023_Appy_Etang_dAppy (8 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.77, 0.88, 0.94, 0.97, 0.78, 0.95, 0.97, 0.88]
# - Moyenne des précisions : 0.89
# - Intervalle de confiance (à 95%) : [0.82, 0.96]
# - Top 5 local des features : ['V124', 'V102', 'V112', 'V33', 'V76']
# =======================================================================================================================================================
#
# Dossier 2023_Arrien_Pic_Midi_Bordes (14 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.84, 0.81, 0.83, 0.76, 0.82, 0.9, 0.81, 0.77, 0.88, 0.89, 0.89, 0.88, 0.84, 0.87]
# - Moyenne des précisions : 0.84
# - Intervalle de confiance (à 95%) : [0.82, 0.87]
# - Top 5 local des features : ['V12', 'V49', 'V50', 'V103', 'V39']
# =======================================================================================================================================================
#
# Dossier 2023_Aston_Plateau_de_Beille (7 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.98, 0.89, 0.96, 0.93, 0.8, 0.92, 0.94]
# - Moyenne des précisions : 0.92
# - Intervalle de confiance (à 95%) : [0.86, 0.97]
# - Top 5 local des features : ['V12', 'V92', 'V22', 'V40', 'V49']
# =======================================================================================================================================================
#
# Dossier 2023_Aulus_Turon_Rose (8 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.81, 0.81, 0.8, 0.95, 0.84, 0.8, 0.83, 0.91]
# - Moyenne des précisions : 0.85
# - Intervalle de confiance (à 95%) : [0.8, 0.89]
# - Top 5 local des features : ['V24', 'V88', 'V20', 'V21', 'V61']
# =======================================================================================================================================================
#
# Dossier 2023_Bonac_Arech (9 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.74, 0.85, 0.85, 0.88, 0.83, 0.88, 0.89, 0.79, 0.83]
# - Moyenne des précisions : 0.84
# - Intervalle de confiance (à 95%) : [0.8, 0.87]
# - Top 5 local des features : ['V30', 'V38', 'V12', 'V85', 'V36']
# =======================================================================================================================================================
#
# Dossier 2023_Couflens_Pouill (4 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.79, 0.86, 0.88, 0.92]
# - Moyenne des précisions : 0.86
# - Intervalle de confiance (à 95%) : [0.78, 0.95]
# - Top 5 local des features : ['V45', 'V107', 'V26', 'V67', 'V22']
# =======================================================================================================================================================
#
# Dossier 2023_Formiguères_Serra_dels_Alarbs (14 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.65, 0.77, 0.9, 0.86, 0.86, 0.82, 0.78, 0.78, 0.62, 0.76, 0.77, 0.93, 0.7, 0.72]
# - Moyenne des précisions : 0.78
# - Intervalle de confiance (à 95%) : [0.73, 0.83]
# - Top 5 local des features : ['V87', 'V24', 'V49', 'V26', 'V23']
# =======================================================================================================================================================
#
# Dossier 2023_Gestiès_Le_Clot (8 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [1.0, 0.88, 0.86, 0.95, 0.93, 0.88, 0.79, 0.95]
# - Moyenne des précisions : 0.9
# - Intervalle de confiance (à 95%) : [0.85, 0.96]
# - Top 5 local des features : ['V62', 'V87', 'V65', 'V99', 'V78']
# =======================================================================================================================================================
#
# Dossier 2023_Les_Angles_Puig_del_Pam (16 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.67, 0.7, 0.62, 0.64, 0.62, 0.69, 0.69, 0.72, 0.88, 0.84, 0.83, 0.9, 0.91, 0.79, 0.83, 0.85]
# - Moyenne des précisions : 0.76
# - Intervalle de confiance (à 95%) : [0.71, 0.82]
# - Top 5 local des features : ['V8', 'V49', 'V45', 'V88', 'V40']
# =======================================================================================================================================================
#
# Dossier 2023_Les_Angles_Roc_dAude (14 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.75, 0.51, 0.61, 0.77, 0.82, 0.7, 0.58, 0.57, 0.74, 0.76, 0.81, 0.8, 0.78, 0.84]
# - Moyenne des précisions : 0.72
# - Intervalle de confiance (à 95%) : [0.66, 0.78]
# - Top 5 local des features : ['V19', 'V29', 'V75', 'V103', 'V24']
# =======================================================================================================================================================
#
# Dossier 2023_Miglos_Pla_de_Montcamp (7 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.74, 0.83, 0.84, 0.77, 0.89, 0.82, 0.83]
# - Moyenne des précisions : 0.82
# - Intervalle de confiance (à 95%) : [0.77, 0.86]
# - Top 5 local des features : ['V106', 'V19', 'V36', 'V62', 'V46']
# =======================================================================================================================================================
#
# Dossier 2023_Montferrier_Mont_dOlmes (7 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.9, 0.84, 0.75, 0.72, 0.73, 0.72, 0.89]
# - Moyenne des précisions : 0.79
# - Intervalle de confiance (à 95%) : [0.72, 0.87]
# - Top 5 local des features : ['V15', 'V24', 'V34', 'V3', 'V77']
# =======================================================================================================================================================
#
# Dossier 2023_Seix_Pic_de_Montbuou (13 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.88, 0.96, 0.98, 0.93, 0.94, 0.98, 0.99, 0.97, 0.91, 0.95, 0.89, 0.94, 0.93]
# - Moyenne des précisions : 0.94
# - Intervalle de confiance (à 95%) : [0.92, 0.96]
# - Top 5 local des features : ['V7', 'V9', 'V42', 'V19', 'V49']
# =======================================================================================================================================================
#
# Dossier 2023_Ustou_Col_dEscots (14 cross validation) :
#
# Gradient Boosting Classifier :
# - Précisions sur les ensembles de test : [0.95, 0.99, 0.98, 0.97, 0.97, 0.95, 0.99, 0.98, 0.96, 0.96, 0.91, 0.93, 0.95, 0.94]
# - Moyenne des précisions : 0.96
# - Intervalle de confiance (à 95%) : [0.94, 0.97]
# - Top 5 local des features : ['V29', 'V49', 'V15', 'V103', 'V52']
# =======================================================================================================================================================
#
# GLOBAL (24 stations) :
#
# Gradient Boosting Classifier :
# - Moyenne globale des précisions : 0.84
# - Intervalle de confiance global (à 95%) : [0.81, 0.87]
# - Top 5 global des features : [('V49', 8), ('V19', 7), ('V12', 6), ('V24', 6), ('V22', 4)]
